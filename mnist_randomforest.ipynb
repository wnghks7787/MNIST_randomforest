# %% [markdown]
# # WandB Init

# %%
# 1. wandb 라이브러리 설치
# !pip install wandb -q

# 2. 로그인 (실행 후 출력되는 링크를 클릭해서 API 키를 복사해 입력창에 붙여넣어)
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: wnghks7787 (wnghks7787-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# 3. 프로젝트 시작 선언
# project: 전체 프로젝트 이름
# name: 이번 실행(Run)의 개별 이름 (예: "random-forest-v1")
wandb.init(project="mnist-ml-project", name="rf-baseline")

# 나중에 모델의 설정값(하이퍼파라미터)도 기록할 수 있어.
wandb.config = {
    "model_type": "random_forest",
    "n_estimators": 100,
    "max_depth": None
}
# Out:
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260428_222438-ovjtrrgu</code>
# Syncing run <strong><a href='https://wandb.ai/wnghks7787-/mnist-ml-project/runs/ovjtrrgu' target="_blank">rf-baseline</a></strong> to <a href='https://wandb.ai/wnghks7787-/mnist-ml-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/wnghks7787-/mnist-ml-project' target="_blank">https://wandb.ai/wnghks7787-/mnist-ml-project</a>
#  View run at <a href='https://wandb.ai/wnghks7787-/mnist-ml-project/runs/ovjtrrgu' target="_blank">https://wandb.ai/wnghks7787-/mnist-ml-project/runs/ovjtrrgu</a>

# %%
from sklearn.datasets import fetch_openml
import numpy as np

# %% [markdown]
# # MNIST 데이터셋 불러오기
# ## MNIST란?
# MNIST는 784 x 784 개의 픽셀로 이루어진 약 7만여 개의 손글씨 데이터입니다.\
# 이 데이터들은 0에서 9까지의 숫자를 가지고 있으며, 흰색과 검은색의 픽셀만을 사용합니다.\
# 이 데이터를 활용하면 AI의 기초를 공부하는데 많은 도움이 될 수 있습니다.

# %%
# MNIST 데이터셋 불러오기
print("데이터 로딩 중...")
mnist = fetch_openml('mnist_784', version=1, as_frame=False)
# Out:
# 데이터 로딩 중...
